# %%
#Geçerli değişken tanımlama
degisken_1=10
Degisken2=20
_degisken3=30

# %%
#Geçersiz değişken tanımlama
-degisken=5
1degsiken=3

# %%
#İnteger - Tamsayı tanımlaması
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
x=5
y="hello world"
print(x)
print(y)
# Out:
# 5
# hello world

# %%
#String - Metinsel içerik tanımlama
b="6alata5aray"
print(type(b))
print(b)
# Out:
# <class 'str'>
# 6alata5aray

# %%
#Tür Dönüşümü
x=10
y=str(x)
print(y,type(y))
# Out:
# 10 <class 'str'>

# %%
#Boolean (True-False) Tanımlaması
d=True
e=False
print(type(e))
print(d)
# Out:
# <class 'bool'>
# True

# %%
#List - Liste tanımlama
my_list=[1,2,3,4,5]
print(type(my_list))
print(my_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]

# %%
#Tuple - Demet tanımlama
my_tuple=(1,2,3,4,5)
print(type(my_tuple))
print(my_tuple)

# %%
#Dictionary Tanımlama Öğrenci Notları Örneği
notlar={"Göktürk":85,
          "Kağan":70,
        "Asena":55
          }
notlar["Asena"]=70
print(notlar)
# Out:
# {'Göktürk': 85, 'Kağan': 70, 'Asena': 70}

# %%
print(notlar.keys())#dict_keys
print(notlar.values())#dict_values
print(notlar.items())#dict_items
# Out:
# dict_keys(['Göktürk', 'Kağan', 'Asena'])
# dict_values([85, 70, 70])
# dict_items([('Göktürk', 85), ('Kağan', 70), ('Asena', 70)])

# %%
#Set - Küme Örneği Bir yazılım etkinliğine katılan kişilerin oluşturduğu kümeler
kodyazanlar={"Ahmet","Mehmet","Ayşe"}
kodyazmayanlar={"Ayşe","Fatma","Veli"}
#Kafasına Göre Takılan Öğrenciler
ortak=kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına Göre Takılan Öğrencilerin Listesi:",ortak)
#Etkinlikte Kod Çalışması Yapmayan Öğrenciler
kod_yazmayan=kodyazmayanlar.difference(kodyazanlar)
print("Etkinlikte Kod Çalışması Yapmayan Öğrencilerin Listesi:",kod_yazmayan)
#Yazılım Eğitiminin Öğrenci İmza Listesi
imza_listesi=kodyazanlar.union(kodyazmayanlar)
print("Etkinlik Katılımcıları:",imza_listesi)
# Out:
# Kafasına Göre Takılan Öğrencilerin Listesi: {'Ayşe'}
# Etkinlikte Kod Çalışması Yapmayan Öğrencilerin Listesi: {'Veli', 'Fatma'}
# Etkinlik Katılımcıları: {'Veli', 'Ahmet', 'Mehmet', 'Ayşe', 'Fatma'}

# %%
giris=input("Lütfen bir sayı giriniz:")
if giris.float():
  num=float(giris)
  print(f"Girdiğiniz sayı:{num},tipi:{type(num)},{abs(num)}")
else:
  print("Lütfen sayı giriniz!")
# Out:
# Lütfen bir sayı giriniz:-5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-d6313f5d4149> in <cell line: 2>()
#       1 giris=input("Lütfen bir sayı giriniz:")
# ----> 2 if giris.float():
#       3   num=float(giris)
#       4   print(f"Girdiğiniz sayı:{num},tipi:{type(num)},{abs(num)}")
#       5 else:
#
# AttributeError: 'str' object has no attribute 'float'
